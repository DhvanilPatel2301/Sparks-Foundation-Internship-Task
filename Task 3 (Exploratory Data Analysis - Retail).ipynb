# %% [markdown]
# # The Sparks Foundation
#
# # GRIP(Graduate Rotational Internship Program) December 2022
#
# ## Name : PATEL DHVANIL VIKRAMKUMAR
#
# ## Domain :  Data Science & Business Analytics
#
# ### TASK-03 (Exploratory Data Analysis - Retail)
#
# ### Problem Statement :
#
# #### 1.Perform 'Exploratory data analysis' on dataset 'SampleSuperstore'
#
# #### 2.As a business manager, try to find out the weak areas where you can work to make more profit.
#
# #### 3.What business problem you can derive by exploring data?

# %%
# Importing all libraries required in this notebook
from pandas import *
from numpy import *

import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Readng the Dataset

# %%
store = read_csv("D:\Dhwanil\M.Sc\GRIP Intenship @ Sparks Foundation\Task 3\SampleSuperstore.csv")
store
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# ### Exploring Data :

# %%
store.head(10)
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 5  Standard Class   Consumer  United States      Los Angeles  California
# 6  Standard Class   Consumer  United States      Los Angeles  California
# 7  Standard Class   Consumer  United States      Los Angeles  California
# 8  Standard Class   Consumer  United States      Los Angeles  California
# 9  Standard Class   Consumer  United States      Los Angeles  California
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# ...

# %%
store.tail(10)
# Out:
#            Ship Mode    Segment        Country         City       State  \
# 9984  Standard Class   Consumer  United States   Long Beach    New York
# 9985  Standard Class   Consumer  United States   Long Beach    New York
# 9986  Standard Class   Consumer  United States  Los Angeles  California
# 9987  Standard Class  Corporate  United States       Athens     Georgia
# 9988  Standard Class  Corporate  United States       Athens     Georgia
# 9989    Second Class   Consumer  United States        Miami     Florida
# 9990  Standard Class   Consumer  United States   Costa Mesa  California
# 9991  Standard Class   Consumer  United States   Costa Mesa  California
# 9992  Standard Class   Consumer  United States   Costa Mesa  California
# 9993    Second Class   Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9984        11561   East  Office Supplies       Labels   31.500        10
# ...

# %% [markdown]
# ### How big is the dataset ?

# %%
store.shape
# Out:
# (9994, 13)

# %% [markdown]
# ####  Conclusion :-
# Here We have 9994 Rows / Records (Including Label) and 13 Columns / Attributes.

# %% [markdown]
# ### Name of all column lable

# %%
store.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %% [markdown]
# ### Now we check for Null value if it's present

# %%
store.isna().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %% [markdown]
# #### Conclusion :
#
# Here there is no Null value present in data.

# %% [markdown]
# ### Descriptive Statistics :

# %%
store.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# #### Conlusion :
# Thus, here Average of sales amount is <b> 229.858001
#
# Average profit is <b> 28.6568

# %% [markdown]
# ### Dropping Duplicate data (Rows/ Records)

# %%
#Before removing 
store.shape
# Out:
# (9994, 13)

# %%
#After removing
store.drop_duplicates(keep = "first", inplace = True)
store.shape
# Out:
# (9977, 13)

# %% [markdown]
# #### Conclusion :
# Thus here our rows/records reduced from <b> 9994 to 9977

# %% [markdown]
# ### Looking for Numerical and Categorical/Ordinal variables or attributes

# %%
store.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %% [markdown]
# #### Conclusion :
# Thus, here we have  <b> 4 Numerical Variables </b> which are
# * Sales
# * Quantity
# * Discount
# * Profit
#
# And we have <b> 1 Ordinal variable </b> Which is
# * Postal Code
#
# All the Other Variables are in <b> Categorical or Qualitative Measure

# %% [markdown]
# ### Now we check for Correlation

# %%
compare=store.loc[:,['Sales','Quantity','Discount','Profit']]
compare.corr()
# Out:
#              Sales  Quantity  Discount    Profit
# Sales     1.000000  0.200722 -0.028311  0.479067
# Quantity  0.200722  1.000000  0.008678  0.066211
# Discount -0.028311  0.008678  1.000000 -0.219662
# Profit    0.479067  0.066211 -0.219662  1.000000

# %%
#Plotting Heatmap for better understanding of above numerical data
compare=store.loc[:,['Sales','Quantity','Discount','Profit']]
correlation=compare.corr()
sns.heatmap(correlation,xticklabels=correlation.columns,yticklabels=correlation.columns,annot=True)
plt.show()

# %% [markdown]
# #### Conclusion :
# Thus From this we may say that ,
# * <b> Sales and Profit </b> are <b> Possitively Correlated
# * <b> Discount and Profit </b> are <b> Negatively Correlated

# %% [markdown]
# ### Now we try to find Unique Categoris in each columns

# %%
for i in store.columns:
    print('Number of unique categories in', i + ' is',store[i].nunique())
# Out:
# Number of unique categories in Ship Mode is 4
# Number of unique categories in Segment is 3
# Number of unique categories in Country is 1
# Number of unique categories in City is 531
# Number of unique categories in State is 49
# Number of unique categories in Postal Code is 631
# Number of unique categories in Region is 4
# Number of unique categories in Category is 3
# Number of unique categories in Sub-Category is 17
# Number of unique categories in Sales is 5825
# Number of unique categories in Quantity is 14
# Number of unique categories in Discount is 12
# Number of unique categories in Profit is 7287

# %% [markdown]
# ### Checking for Outliers

# %%
store.boxplot()
plt.show()

# %% [markdown]
# #### Conclusion :
# Here from this box plot we can say that our <b> Sales and Profit </b> columns are having outliers

# %% [markdown]
# ### Regionwise data distribution of other parameters

# %%
sns.pairplot(data=store,hue='Region')
plt.show()

# %% [markdown]
# #### Conclusion :
# From above graph wo can see the relation different parameters. we can see <b>regionwise performance</b> of different different parameters.

# %% [markdown]
# ### Now we check Distribution of our Quantitative Variables / Attributes

# %%
fig,axes = plt.subplots(2,2,figsize=(16,8))
fig.suptitle("Distribution Plots",fontsize=16)
sns.distplot(store['Sales'],ax=axes[0,0])
sns.distplot(store['Profit'],ax=axes[0,1])
sns.distplot(store['Discount'],ax=axes[1,0])
sns.distplot(store['Quantity'],ax=axes[1,1])
plt.show()

# %% [markdown]
# ### Now we check for state wise total sales

# %%
sales=store.groupby("State").Sales.sum()
profit=store.groupby("State").Profit.sum()

# %%
plt.style.use('seaborn')
sales.plot(kind ='bar', figsize =(16,7), fontsize =15, color = "Blue")
plt.xlabel("States", fontsize =20)
plt.ylabel("Total Sales",fontsize =20)
plt.title("States V/s. Sales",fontsize =25)
plt.show()

# %% [markdown]
# #### Conlusion :
# This here we can see top 10 states with Hieght sales and those are,
# * California
# * New York
# * Texas
# * Washington
# * Pennsylvania
# * Florida
# * Illinois
# * Ohio
# * Michigan
# * Virginia
#
# In Order to <b>increase sales</b> we need to keep this states in mind

# %% [markdown]
# ### Now we check for profit of each state

# %%
plt.style.use('seaborn')
profit.plot(kind ='bar', figsize =(16,7), fontsize =15, color = "Green")
plt.xlabel("States", fontsize =20)
plt.ylabel("Total Profit",fontsize =20)
plt.title("States V/s. Sales",fontsize =25)
plt.show()

# %% [markdown]
# #### Conclusion :
# Thus, from this chart we may say that we have ,
# * <b> 2 Major States earning Profit
#         * California
#         * New York
# * <b> 1 Sate Having Maximum loss
#     * Texas

# %% [markdown]
# ### Ship Mode and it's impact on sales

# %% [markdown]
# #### Shipmode wise total sales

# %%
x= store['Ship Mode']. unique()
x.sort()
x
# Out:
# array(['First Class', 'Same Day', 'Second Class', 'Standard Class'],
#       dtype=object)

# %%
y = store.groupby(['Ship Mode'])['Sales'].sum()
y
# Out:
# Ship Mode
# First Class       3.514284e+05
# Same Day          1.283631e+05
# Second Class      4.591936e+05
# Standard Class    1.358216e+06
# Name: Sales, dtype: float64

# %% [markdown]
# #### Shipmode wise total profit

# %%
y_prof = store.groupby(['Ship Mode'])['Profit'].sum()
y_prof
# Out:
# Ship Mode
# First Class        48969.8399
# Same Day           15891.7589
# Second Class       57446.6354
# Standard Class    164088.7875
# Name: Profit, dtype: float64

# %% [markdown]
# #### Shipmode wise total discount

# %%
y_dis = store.groupby(['Ship Mode'])['Discount'].sum()
y_dis
# Out:
# Ship Mode
# First Class       253.17
# Same Day           82.75
# Second Class      270.15
# Standard Class    955.02
# Name: Discount, dtype: float64

# %%
fig,(ax1, ax2, ax3) =  plt.subplots(1,3,figsize=(20,6))
ax1.bar (x,y,color =['blue','red','yellow','green'])                          
ax2.bar (x,y_prof,color=['blue','red','yellow','green'])
ax3.bar(x,y_dis,color=['blue','red','yellow','green'])
ax1.set_title('Shipmodewise Total Sales')
ax2.set_title('Shipeodewise Total Profit')
ax3.set_title('Shipmodewise Total Discount')
plt.show()

# %% [markdown]
# #### Conclusion :
# Here by looking these graphs we can say that ,
# * <b>Total sales for Standard Class is High</b> and that will result into <b>High Profit and High Discount</b>
# * So we have to use this strategies to imporve our sales and profit

# %% [markdown]
# ### Segment wise  sales and it's impact

# %% [markdown]
# #### Segment Wise Total Sales

# %%
s1 = store['Segment'].unique()
s1
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %% [markdown]
# <b> Here There are 3 Segments </b>
# * Consumer
# * Corporate
# * Home Office

# %%
y2 = store.groupby(['Segment'])['Sales'].sum()
y2
# Out:
# Segment
# Consumer       1.161401e+06
# Corporate      7.061464e+05
# Home Office    4.296531e+05
# Name: Sales, dtype: float64

# %% [markdown]
# #### Segment Wise Total Profit

# %%
y2_prof = store.groupby(['Segment'])['Profit'].sum()
y2_prof
# Out:
# Segment
# Consumer       134119.2092
# Corporate       91979.1340
# Home Office     60298.6785
# Name: Profit, dtype: float64

# %% [markdown]
# #### Segment Wise Total Discount

# %%
y2_disc = store.groupby(['Segment'])['Discount'].sum()
y2_disc
# Out:
# Segment
# Consumer       820.91
# Corporate      477.85
# Home Office    262.33
# Name: Discount, dtype: float64

# %%
fig,(bx1,bx2,bx3) = plt.subplots(1,3,figsize=(20,6))
bx1.bar(s1,y2,color = ['green','red','blue'])
bx2.bar(s1,y2_prof, color = ['green','red','blue'])
bx3.bar(s1,y2_disc,color = ['green','red','blue'])
bx1.set_title('Segment Wise Total Sales',fontsize=20)
bx2.set_title('Segment Wise Total Profit',fontsize=20)
bx3.set_title('Segment Wise Total Discount',fontsize=20)
plt.show()

# %% [markdown]
# #### Conclusion :
# Thus from this graphs we can say that <b> Consumer Segment </b> is performing good as we give more discount on this.
#
# So, <b>in-order to increase sales and profit</b> we need to gave discount to <b> Corporate and Home-Office segment </b> also.

# %% [markdown]
# ### Region Wise Total Sales and Profit Performance

# %%
r1=store['Region'].unique()
r1
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %% [markdown]
# #### Region WIse Total Sales

# %%
y3 = store.groupby(['Region'])['Sales'].sum()
y3
# Out:
# Region
# Central    501239.8908
# East       678781.2400
# South      391721.9050
# West       725457.8245
# Name: Sales, dtype: float64

# %% [markdown]
# #### Region WIse Total Profit

# %%
y3_prof = store.groupby(['Region'])['Profit'].sum()
y3_prof
# Out:
# Region
# Central     39706.3625
# East        91522.7800
# South       46749.4303
# West       108418.4489
# Name: Profit, dtype: float64

# %% [markdown]
# #### Region WIse Total Discount

# %%
y3_disc = store.groupby(['Region'])['Discount'].sum()
y3_disc
# Out:
# Region
# Central    558.34
# East       414.00
# South      238.55
# West       350.20
# Name: Discount, dtype: float64

# %%
fig,(cx1,cx2,cx3) = plt.subplots(1,3,figsize=(20,6))
cx1.bar(r1,y3,color = ['blue','red','yellow','green'])
cx2.bar(r1,y3_prof,color = ['blue','red','yellow','green'])
cx3.bar(r1,y3_disc,color = ['blue','red','yellow','green'])
cx1.set_title('Region WIse Total Sales', fontsize = 15)
cx2.set_title('Region WIse Total Profit',fontsize = 15)
cx3.set_title('Region WIse Total Discount',fontsize = 15)
plt.show()

# %% [markdown]
# #### Conclusion :
# from this graph we may say that Total sales and Profit is maximum in <b> East Region </b>,Though we are giving more discount to <b> South Region</b>

# %% [markdown]
# ### Category Wise Total Sales and Profit Performance

# %%
c1=store['Category'].unique()
c1
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %% [markdown]
# #### Conclusion :
# Hence we have 3 Categories
# * Furniture
# * Office Supplies
# * Technology

# %% [markdown]
# #### Category WIse Total Sales

# %%
y4 = store.groupby(['Category'])['Sales'].sum()
y4
# Out:
# Category
# Furniture          741999.7953
# Office Supplies    719047.0320
# Technology         836154.0330
# Name: Sales, dtype: float64

# %% [markdown]
# #### Category WIse Total Profit

# %%
y4_prof = store.groupby(['Category'])['Profit'].sum()
y4_prof
# Out:
# Category
# Furniture           18451.2728
# Office Supplies    122490.8008
# Technology         145454.9481
# Name: Profit, dtype: float64

# %% [markdown]
# #### Category WIse Total Discount

# %%
y4_disc = store.groupby(['Category'])['Discount'].sum()
y4_disc
# Out:
# Category
# Furniture          368.89
# Office Supplies    947.80
# Technology         244.40
# Name: Discount, dtype: float64

# %%
fig,(dx1,dx2,dx3) = plt.subplots(1,3,figsize=(20,6))
dx1.bar(c1,y4,color = ['blue','red','green'])
dx2.bar(c1,y4_prof,color = ['blue','red','green'])
dx3.bar(c1,y4_disc,color = ['blue','red','green'])
dx1.set_title('Category WIse Total Sales', fontsize = 15)
dx2.set_title('Category WIse Total Profit',fontsize = 15)
dx3.set_title('Category WIse Total Discount',fontsize = 15)
plt.show()

# %% [markdown]
# #### Conclusion :
# Thus, from these graphs we may say that Total sales and Profit are Maximum for <b> Technology Category </b> , though we are giving maximum Discount to <b> Office Suppliers Category </b>

# %% [markdown]
# ### Sub-Category Wise Order Counts

# %%
plt.figure(figsize = (20,10))
sns.countplot(x=store['Sub-Category'],orient= 'h',order=(store['Sub-Category'].value_counts()).index)
plt.title('Sub-Category Wise Sales Count',fontsize=15)
plt.show()

# %% [markdown]
# #### Conclusion :
# Here by looking this graph we can say that <b>80% of orders are for 8 categories.</b>

# %%
plt.figure(figsize=(14,8))
sns.countplot(x='Sub-Category',hue='Segment',data=store)
plt.show()

# %% [markdown]
# ### Conclusion :
# * <b> Ship Mode </b>  -Standard Class has highest profit.
#
# * <b> Region </b> - Central and South region Profits are considerably less considering the Sales
#
# * <b> Category </b> -Furniture Category has high sales, but too less profits so this situation is matter of concern
#
# * In <b> Office Supplies </b> - we are providing Maximum discount bt at the same time technology category is earning more profit
#
# * In The least selling Copiers is giving maximum profit
#
# * <b> Profit seems to be best if discount is (0-15)%  it declines fast if discount is greater than 70%.

# %% [markdown]
# ### Suggestions :
# * find out <b> why very few states is having maximum profit</b> amd try to sell product in those states where the sales is very low.
# * Find out Causes for having loss in country having sales at good amount.
# * <b> keep discount rate below 30%, as it declines profit if its more than 30 % </b>
# * <b> we need to increase discount to Corporate and Home-Office segment </b> to increase sales and profit.
# * <b> Increase the sale of Copiers to get more profit.

# %% [markdown]
# ## Thank You !
